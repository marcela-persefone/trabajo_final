# %% [markdown]
# # Instalar librerías, Cargar dataset y crear variable objetivo

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df_raw = pd.read_csv('retail_data_sample.csv')
# Crear variable objetivo: Compra_online
df_raw['ventas'] = (df_raw['total_sales'] > 1500 ).astype(int)
df_raw.head()
# Out:
#    customer_id  age  gender income_bracket loyalty_program  membership_years  \
# 0        40891   65    Male           High             Yes                 9
# 1       267732   31  Female            Low              No                 3
# 2       262622   52    Male         Medium              No                 4
# 3       295896   64  Female         Medium             Yes                 7
# 4       208360   77   Other         Medium              No                 8
#
#   churned marital_status  number_of_children education_level  ...  \
# 0      No       Divorced                   2     High School  ...
# 1     Yes         Single                   0      Bachelor's  ...
# 2     Yes         Single                   3        Master's  ...
# 3      No         Single                   2        Master's  ...
# 4     Yes       Divorced                   3             PhD  ...
#
#   holiday_season  season weekend  customer_support_calls email_subscriptions  \
# ...

# %% [markdown]
# # Visualización exploratoria

# %% [markdown]
# ## Gráfico 1: Histograma de distribución de edad

# %%
df_raw['age'].dropna().plot(kind='hist', bins=30, edgecolor='black')
plt.title('Distribución de Edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ## Gráfico 2: Distribución de Preferencia de Canal de Compra

# %%
df_raw['compra_online'].value_counts().plot(kind='bar', color='lightgreen')
plt.title('Distribución de Preferencia de Canal de Compra')
plt.xlabel("Compra Online (1 = Sí, 0 = No)")
plt.xticks([0, 1], ["Tienda Física", "Online"])
plt.ylabel('Cantidad de Clientes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'compra_online'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ...

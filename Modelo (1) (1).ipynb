# %% [markdown]
# # PASO 1: Instalar librerías

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## PASO 1.1: Importar herramientas de modelado y evaluación

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_curve,
    roc_auc_score
)

# %% [markdown]
# # PASO 2: Cargar dataset  y crear variable objetivo

# %%
df = pd.read_csv("retail_data_sample.csv")
# Crear variable objetivo: Compra_online
df["compra_online"] = (df["online_purchases"] > df["in_store_purchases"]).astype(int)

# %% [markdown]
# * (df["online_purchases"] > df["in_store_purchases"]) : Compara cada fila para ver si el número de compras online es mayor al número de compras en tienda física.
#
# Esto devuelve una serie de valores True o False
# * .astype(int)
# Convierte los True en 1 y los False en 0, Se convierte el resultado booleano
# * df["compra_online"] = Asigna ese resultado a una nueva columna en el DataFrame, llamada compra_online.

# %% [markdown]
# # Paso 3: Revisar estructura del dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 79 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_id                10000 non-null  int64
#  1   age                        10000 non-null  int64
#  2   gender                     10000 non-null  object
#  3   income_bracket             10000 non-null  object
#  4   loyalty_program            10000 non-null  object
#  5   membership_years           10000 non-null  int64
#  6   churned                    10000 non-null  object
#  7   marital_status             10000 non-null  object
#  8   number_of_children         10000 non-null  int64
#  9   education_level            10000 non-null  object
#  10  occupation                 10000 non-null  object
#  11  transaction_id             10000 non-null  int64
#  12  transaction_date           10000 non-null  object
#  13  product_id                 10000 non-null  int64
#  14  product_category           10000 non-null  object
#  15  quantity                   10000 non-null  int64
#  16  unit_price                 10000 non-null  float64
#  17  discount_applied           10000 non-null  float64
#  18  payment_method             10000 non-null  object
#  19  store_location             10000 non-null  object
#  20  transaction_hour           10000 non-null  int64
#  21  day_of_week                10000 non-null  object
#  22  week_of_year               10000 non-null  int64
#  23  month_of_year              10000 non-null  int64
#  24  avg_purchase_value         10000 non-null  float64
#  25  purchase_frequency         10000 non-null  object
#  26  last_purchase_date         10000 non-null  object
#  27  avg_discount_used          10000 non-null  float64
#  28  preferred_store            10000 non-null  object
#  29  online_purchases           10000 non-null  int64
#  30  in_store_purchases         10000 non-null  int64
#  31  avg_items_per_transaction  10000 non-null  float64
#  32  avg_transaction_value      10000 non-null  float64
#  33  total_returned_items       10000 non-null  int64
#  34  total_returned_value       10000 non-null  float64
#  35  total_sales                10000 non-null  float64
#  36  total_transactions         10000 non-null  int64
#  37  total_items_purchased      10000 non-null  int64
#  38  total_discounts_received   10000 non-null  float64
#  39  avg_spent_per_category     10000 non-null  float64
#  40  max_single_purchase_value  10000 non-null  float64
#  41  min_single_purchase_value  10000 non-null  float64
#  42  product_name               10000 non-null  object
#  43  product_brand              10000 non-null  object
#  44  product_rating             10000 non-null  float64
#  45  product_review_count       10000 non-null  int64
#  46  product_stock              10000 non-null  int64
#  47  product_return_rate        10000 non-null  float64
#  48  product_size               10000 non-null  object
#  49  product_weight             10000 non-null  float64
#  50  product_color              10000 non-null  object
#  51  product_material           10000 non-null  object
#  52  product_manufacture_date   10000 non-null  object
#  53  product_expiry_date        10000 non-null  object
#  54  product_shelf_life         10000 non-null  int64
#  55  promotion_id               10000 non-null  int64
#  56  promotion_type             10000 non-null  object
#  57  promotion_start_date       10000 non-null  object
#  58  promotion_end_date         10000 non-null  object
#  59  promotion_effectiveness    10000 non-null  object
#  60  promotion_channel          10000 non-null  object
#  61  promotion_target_audience  10000 non-null  object
#  62  customer_zip_code          10000 non-null  float64
#  63  customer_city              10000 non-null  object
#  64  customer_state             10000 non-null  object
#  65  store_zip_code             10000 non-null  float64
#  66  store_city                 10000 non-null  object
#  67  store_state                10000 non-null  object
#  68  distance_to_store          10000 non-null  float64
#  69  holiday_season             10000 non-null  object
#  70  season                     10000 non-null  object
#  71  weekend                    10000 non-null  object
#  72  customer_support_calls     10000 non-null  float64
#  73  email_subscriptions        10000 non-null  object
#  74  app_usage                  10000 non-null  object
#  75  website_visits             10000 non-null  float64
#  76  social_media_engagement    10000 non-null  object
#  77  days_since_last_purchase   10000 non-null  float64
#  78  compra_online              10000 non-null  int64
# dtypes: float64(21), int64(20), object(38)
# memory usage: 6.0+ MB

# %% [markdown]
# # Paso 4: Descripción estadística general

# %%
df.describe(include='all')
# Out:
#           customer_id           age gender income_bracket loyalty_program  \
# count    10000.000000  10000.000000  10000          10000           10000
# unique            NaN           NaN      3              3               2
# top               NaN           NaN  Other            Low              No
# freq              NaN           NaN   3391           3358            5094
# mean    157765.176700     48.040000    NaN            NaN             NaN
# std      90853.288948     17.972192    NaN            NaN             NaN
# min         17.000000     18.000000    NaN            NaN             NaN
# 25%      79964.250000     33.000000    NaN            NaN             NaN
# 50%     158743.000000     48.000000    NaN            NaN             NaN
# 75%     236601.750000     64.000000    NaN            NaN             NaN
# max     315087.000000     79.000000    NaN            NaN             NaN
#
#         membership_years churned marital_status  number_of_children  \
# count       10000.000000   10000          10000        10000.000000
# unique               NaN       2              3                 NaN
# top                  NaN     Yes        Married                 NaN
# freq                 NaN    5049           3399                 NaN
# mean            4.486800     NaN            NaN            2.009800
# std             2.879141     NaN            NaN            1.412835
# min             0.000000     NaN            NaN            0.000000
# 25%             2.000000     NaN            NaN            1.000000
# 50%             4.000000     NaN            NaN            2.000000
# 75%             7.000000     NaN            NaN            3.000000
# max             9.000000     NaN            NaN            4.000000
#
#        education_level  ... holiday_season  season weekend  \
# count            10000  ...          10000   10000   10000
# unique               4  ...              2       4       2
# top                PhD  ...             No  Summer      No
# freq              2521  ...           5028    2579    5028
# mean               NaN  ...            NaN     NaN     NaN
# std                NaN  ...            NaN     NaN     NaN
# min                NaN  ...            NaN     NaN     NaN
# 25%                NaN  ...            NaN     NaN     NaN
# 50%                NaN  ...            NaN     NaN     NaN
# 75%                NaN  ...            NaN     NaN     NaN
# max                NaN  ...            NaN     NaN     NaN
#
#         customer_support_calls email_subscriptions  app_usage  website_visits  \
# count             10000.000000               10000      10000    10000.000000
# unique                     NaN                   2          3             NaN
# top                        NaN                  No       High             NaN
# freq                       NaN                5011       3402             NaN
# mean                  9.430800                 NaN        NaN       49.865400
# std                   5.727381                 NaN        NaN       28.706638
# min                   0.000000                 NaN        NaN        0.000000
# 25%                   5.000000                 NaN        NaN       25.000000
# 50%                   9.000000                 NaN        NaN       50.000000
# 75%                  14.000000                 NaN        NaN       74.000000
# max                  19.000000                 NaN        NaN       99.000000
#
#         social_media_engagement days_since_last_purchase compra_online
# count                     10000             10000.000000  10000.000000
# unique                        3                      NaN           NaN
# top                        High                      NaN           NaN
# freq                       3353                      NaN           NaN
# mean                        NaN               182.004200      0.503600
# std                         NaN               105.364709      0.500012
# min                         NaN                 0.000000      0.000000
# 25%                         NaN                90.000000      0.000000
# 50%                         NaN               181.000000      1.000000
# 75%                         NaN               274.000000      1.000000
# max                         NaN               364.000000      1.000000
#
# [11 rows x 79 columns]

# %% [markdown]
# # Visualización exploratoria

# %% [markdown]
# ## Gráfico 1: Histograma de distribución de edad

# %%
df['age'].dropna().plot(kind='hist', bins=30, edgecolor='black')
plt.title('Distribución de Edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ## Gráfico 2: Distribución de Preferencia de Canal de Compra

# %%
df['compra_online'].value_counts().plot(kind='bar', color='lightgreen')
plt.title('Distribución de Preferencia de Canal de Compra')
plt.xlabel("Compra Online (1 = Sí, 0 = No)")
plt.xticks([0, 1], ["Tienda Física", "Online"])
plt.ylabel('Cantidad de Clientes')
plt.show()

# %% [markdown]
#  # Paso 5: Evaluación del modelo antes de limpiar los datos

# %%
# Crear variable objetivo
df["compra_online"] = (df["online_purchases"] > df["in_store_purchases"]).astype(int)

# Seleccionar variables sin limpieza
df_before = df[["age", "website_visits",]].dropna()
Xb = df_before.copy()
yb = df.loc[df_before.index, "compra_online"]

# División entrenamiento / prueba
Xb_train, Xb_test, yb_train, yb_test = train_test_split(Xb, yb, test_size=0.3, random_state=42)

# Entrenar modelo
model_before = LogisticRegression(max_iter=1000)
model_before.fit(Xb_train, yb_train)

# Evaluar exactitud
yb_pred = model_before.predict(Xb_test)
acc_before = accuracy_score(yb_test, yb_pred)
print("✅ Exactitud antes de la limpieza:", round(acc_before, 4))
# Out:
# ✅ Exactitud antes de la limpieza: 0.4947

# %% [markdown]
# #### Este valor indica que el modelo de regresión logística logró una exactitud del 49.47% al predecir si un cliente prefiere comprar en línea (compra_online = 1) o en tienda física (compra_online = 0), utilizando únicamente las variables Edad (age), Visitas al sitio web (website_visits).

# %% [markdown]
# # Paso 6: Preparación del dataset: limpieza, imputación y codificación

# %%
selected_features = [
    "age", "income_bracket", "purchase_frequency",
    "social_media_engagement", "website_visits", "avg_discount_used",
    "email_subscriptions", "gender","income_bracket"
]

df_model = df[selected_features + ["compra_online"]].copy()

num_cols = df_model.select_dtypes(include=["float64", "int64"]).columns
imputer = SimpleImputer(strategy="median")
df_model[num_cols] = imputer.fit_transform(df_model[num_cols])

df_model = pd.get_dummies(df_model, drop_first=True)

X = df_model.drop(columns=["compra_online"])
y = df_model["compra_online"]

scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Paso 7: Evaluación del modelo después de la limpieza

# %%
Xc = X_scaled
yc = y

Xc_train, Xc_test, yc_train, yc_test = train_test_split(Xc, yc, test_size=0.3, random_state=42)

model_after = LogisticRegression(max_iter=200)
model_after.fit(Xc_train, yc_train)
yc_pred = model_after.predict(Xc_test)

acc_after = accuracy_score(yc_test, yc_pred)
print("✅ Exactitud después de la limpieza:", round(acc_after, 4))

# %% [markdown]
# #### Modelo regresion logistica

# %%
log_model = LogisticRegression(max_iter=300)
log_model.fit(X_train, y_train)
log_pred = log_model.predict(X_test)
log_prob = log_model.predict_proba(X_test)[:, 1]

print("📊 Logistic Regression Accuracy:", round(accuracy_score(y_test, log_pred), 4))
print(classification_report(y_test, log_pred))
# Out:
# 📊 Logistic Regression Accuracy: 0.5007
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.36      0.42      1529
#          1.0       0.49      0.65      0.56      1471
#
#     accuracy                           0.50      3000
#    macro avg       0.50      0.50      0.49      3000
# weighted avg       0.50      0.50      0.49      3000

# %%
fpr, tpr, _ = roc_curve(y_test, log_prob)
roc_auc = roc_auc_score(y_test, log_prob)

plt.figure(figsize=(8, 5))
plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('Falsos Positivos')
plt.ylabel('Verdaderos Positivos')
plt.title('Curva ROC - Regresión Logística')
plt.legend()
plt.grid(True)
plt.show()

ConfusionMatrixDisplay.from_estimator(log_model, X_test, y_test, cmap="Blues")
plt.title("Matriz de Confusión - Regresión Logística")
plt.show()

# %%
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)
knn_pred = knn_model.predict(X_test)

print("🔎 KNN Accuracy:", round(accuracy_score(y_test, knn_pred), 4))
print(classification_report(y_test, knn_pred))
# Out:
# 🔎 KNN Accuracy: 0.498
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.47      0.49      1529
#          1.0       0.49      0.52      0.51      1471
#
#     accuracy                           0.50      3000
#    macro avg       0.50      0.50      0.50      3000
# weighted avg       0.50      0.50      0.50      3000

# %%
tree_model = DecisionTreeClassifier(random_state=42)
tree_model.fit(X_train, y_train)
tree_pred = tree_model.predict(X_test)

print("🌳 Árbol de Decisión Accuracy:", round(accuracy_score(y_test, tree_pred), 4))
print(classification_report(y_test, tree_pred))

plt.figure(figsize=(14, 6))
plot_tree(tree_model, filled=True, max_depth=3, feature_names=X.columns, class_names=["Tienda", "Online"])
plt.title("Árbol de Decisión (primeros niveles)")
plt.show()
# Out:
# 🌳 Árbol de Decisión Accuracy: 0.5057
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.49      0.50      1529
#          1.0       0.50      0.52      0.51      1471
#
#     accuracy                           0.51      3000
#    macro avg       0.51      0.51      0.51      3000
# weighted avg       0.51      0.51      0.51      3000

# %%
importances = rf_model.feature_importances_
features = X.columns
feat_importance = pd.Series(importances, index=features).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=feat_importance.values, y=feat_importance.index)
plt.title("Importancia de variables (Random Forest)")
plt.xlabel("Importancia")
plt.ylabel("Variable")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 3
#       1 importances = rf_model.feature_importances_
#       2 features = X.columns
# ----> 3 feat_importance = pd.Series(importances, index=features).sort_values(ascending=False)
#       5 plt.figure(figsize=(10, 6))
#       6 sns.barplot(x=feat_importance.values, y=feat_importance.index)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/series.py:575, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     573     index = default_index(len(data))
#     574 elif is_list_like(data):
# --> 575     com.require_length_match(data, index)
#     577 # create/copy the manager
#     578 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pandas/core/common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (22) does not match length of index (13)

# %%
models = {
    "Random Forest": rf_model,
    "Regresión Logística": LogisticRegression(max_iter=300),
    "KNN": KNeighborsClassifier(),
    "Árbol de Decisión": DecisionTreeClassifier()
}

print("📊 Comparación de exactitud (Validación Cruzada - 5 folds):\n")
for name, model in models.items():
    scores = cross_val_score(model, X_scaled, y, cv=5, scoring="accuracy")
    print(f"{name:20}: {scores.mean():.3f} ± {scores.std():.3f}")
# Out:
# 📊 Comparación de exactitud (Validación Cruzada - 5 folds):
#
# Random Forest       : 0.492 ± 0.007
# Regresión Logística : 0.504 ± 0.012
# KNN                 : 0.497 ± 0.007
# Árbol de Decisión   : 0.497 ± 0.013
